# %%
import pandas as pd
data = pd.read_csv('C:/Users/19054/Desktop/mlp/GOOG1.csv', skipinitialspace=True)
print(data.info())
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1763 entries, 0 to 1762
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1763 non-null   object
#  1   Open       1763 non-null   float64
#  2   High       1763 non-null   float64
#  3   Low        1763 non-null   float64
#  4   Close      1763 non-null   float64
#  5   Adj Close  1763 non-null   float64
#  6   Volume     1763 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.5+ KB
# None
#             Date         Open         High          Low        Close  \
# 0     2013-10-29   507.647217   516.533875   504.857666   516.185181
# 1     2013-10-30   516.778015   516.817810   511.084320   513.286072
# 2     2013-10-31   512.543884   518.815369   510.073120   513.365784
# 3     2013-11-01   513.968506   516.065674   510.636017   511.602386
# 4     2013-11-04   513.824036   514.257446   509.106750   511.139130
# ...

# %%
import datetime as dt
from datetime import datetime
# Select features (columns) to be involved intro training and predictions
columns = list(data)[1:6]

# Extract dates (will be used in visualization)
datelist_train = list(data['Date'])
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

print('Training set shape == {}'.format(data.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(columns))
# Out:
# Training set shape == (1763, 7)
# All timestamps == 1763
# Featured selected: ['Open', 'High', 'Low', 'Close', 'Adj Close']

# %%
data['Open']
# Out:
# 0        507.647217
# 1        516.778015
# 2        512.543884
# 3        513.968506
# 4        513.824036
#            ...
# 1758    1593.050049
# 1759    1626.069946
# 1760    1625.010010
# 1761    1595.670044
# 1762    1559.739990
# Name: Open, Length: 1763, dtype: float64

# %%
data['Open'].hist()
m= data['Open'].mean()

# %%
# Correlation plot for the daily returns
sns.heatmap(data.corr(), annot=True, cmap='summer')

# %%
data['Open'].kurtosis()
# Out:
# -0.9575831851749674

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
k = sns.pairplot(data)
k.savefig("output.png")

# %%
sns.distplot(data.Open,color='green',bins=100)

# %%
sns.distplot(data.Close,color='red',bins=100)

# %%
sns.heatmap(data.corr(),annot=True)

# %%
import pandas as pd
data1 = pd.read_csv('C:/Users/19054/Desktop/mlp/GOOG1.csv', index_col='Date', parse_dates=True)
print(data1.info())
data1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1763 entries, 2013-10-29 to 2020-10-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1763 non-null   float64
#  1   High       1763 non-null   float64
#  2   Low        1763 non-null   float64
#  3   Close      1763 non-null   float64
#  4   Adj Close  1763 non-null   float64
#  5   Volume     1763 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 96.4 KB
# None
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2013-10-29   507.647217   516.533875   504.857666   516.185181   516.185181
# 2013-10-30   516.778015   516.817810   511.084320   513.286072   513.286072
# 2013-10-31   512.543884   518.815369   510.073120   513.365784   513.365784
# 2013-11-01   513.968506   516.065674   510.636017   511.602386   511.602386
# 2013-11-04   513.824036   514.257446   509.106750   511.139130   511.139130
# ...

# %%
title = 'The google stock price'
ylabel='Price'
ax = data[['Open','Close']].plot(figsize=(12,6),title=title)
ax.autoscale(axis='x',tight=True)
ax.set(ylabel=ylabel);

# %%
#introducing the first variable
data1['open_close']=((data1['Open']-data1['Close'].shift(1))/data1['Close'].shift(1))*100

# %%
import datetime as dt

import pandas as pd
d= data1['Weekday'] = data1.index.day_name()
order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
sns.boxplot(x=d,
            y=data1['open_close'], order=order);

# %%
#2nd vasriable
data1['high_low']=((data1['High']-data1['Low'])/data1['Low'])*100

# %%
import pandas as pd
d= data1['Weekday'] = data1.index.day_name()
order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
sns.boxplot(x=d,
            y=data1['high_low'], order=order);
