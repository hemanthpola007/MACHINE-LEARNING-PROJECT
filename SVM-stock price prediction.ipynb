# %%
import pandas as pd
import datetime as dt
from datetime import datetime
data = pd.read_csv('C:/Users/19054/Desktop/mlp/GOOG.csv')
print(data.info())
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       255 non-null    object
#  1   Open       255 non-null    float64
#  2   High       255 non-null    float64
#  3   Low        255 non-null    float64
#  4   Close      255 non-null    float64
#  5   Adj Close  255 non-null    float64
#  6   Volume     255 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.1+ KB
# None
#            Date         Open         High          Low        Close  \
# 0    2019-10-29  1276.229980  1281.589966  1257.212036  1262.619995
# 1    2019-10-30  1252.969971  1269.359985  1252.000000  1261.290039
# 2    2019-10-31  1261.280029  1267.670044  1250.843018  1260.109985
# 3    2019-11-01  1265.000000  1274.619995  1260.500000  1273.739990
# 4    2019-11-04  1276.449951  1294.130005  1276.354980  1291.369995
# ...

# %%
#data training
data = data.head(len(data)-234)
data
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-10-29  1276.229980  1281.589966  1257.212036  1262.619995
# 1   2019-10-30  1252.969971  1269.359985  1252.000000  1261.290039
# 2   2019-10-31  1261.280029  1267.670044  1250.843018  1260.109985
# 3   2019-11-01  1265.000000  1274.619995  1260.500000  1273.739990
# 4   2019-11-04  1276.449951  1294.130005  1276.354980  1291.369995
# 5   2019-11-05  1292.890015  1298.930054  1291.229004  1292.030029
# 6   2019-11-06  1289.459961  1293.729980  1282.500000  1291.800049
# 7   2019-11-07  1294.280029  1323.739990  1294.244995  1308.859985
# 8   2019-11-08  1305.280029  1318.000000  1304.364990  1311.369995
# 9   2019-11-11  1303.180054  1306.425049  1297.410034  1299.189941
# 10  2019-11-12  1300.000000  1310.000000  1295.770020  1298.800049
# 11  2019-11-13  1294.069946  1304.300049  1293.510010  1298.000000
# 12  2019-11-14  1297.500000  1317.000000  1295.650024  1311.459961
# ...

# %%
actual_price = data.tail(1)
actual_price
# Out:
#           Date         Open         High          Low        Close  \
# 20  2019-11-26  1309.859985  1314.800049  1305.089966  1313.550049
#
#       Adj Close   Volume
# 20  1313.550049  1069700

# %%
#data training
data1 = data.head(len(data)-1)

# %%
data1
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-10-29  1276.229980  1281.589966  1257.212036  1262.619995
# 1   2019-10-30  1252.969971  1269.359985  1252.000000  1261.290039
# 2   2019-10-31  1261.280029  1267.670044  1250.843018  1260.109985
# 3   2019-11-01  1265.000000  1274.619995  1260.500000  1273.739990
# 4   2019-11-04  1276.449951  1294.130005  1276.354980  1291.369995
# 5   2019-11-05  1292.890015  1298.930054  1291.229004  1292.030029
# 6   2019-11-06  1289.459961  1293.729980  1282.500000  1291.800049
# 7   2019-11-07  1294.280029  1323.739990  1294.244995  1308.859985
# 8   2019-11-08  1305.280029  1318.000000  1304.364990  1311.369995
# 9   2019-11-11  1303.180054  1306.425049  1297.410034  1299.189941
# 10  2019-11-12  1300.000000  1310.000000  1295.770020  1298.800049
# 11  2019-11-13  1294.069946  1304.300049  1293.510010  1298.000000
# 12  2019-11-14  1297.500000  1317.000000  1295.650024  1311.459961
# ...

# %%
#storing independent and dependent data
days = list()
Adj_closes = list()

# %%
#get the date and the open price values
data1_days = data1.loc[:,'Date']
data1_adj_close = data1.loc[:, 'Adj Close']

# %%
#creating independent data set
for day in data1_days:
    #print(day)
    #print(day.split('-')[2])
    days.append( [int(day.split('-')[2])])
#creating the dependent datset
for adj_close in data1_adj_close:
    Adj_closes.append(float(adj_close))

# %%
#checking the values stored
days, Adj_closes
# Out:
# ([[29],
#   [30],
#   [31],
#   [1],
#   [4],
#   [5],
#   [6],
#   [7],
#   [8],
#   [11],
#   [12],
#   [13],
#   [14],
#   [15],
#   [18],
#   [19],
#   [20],
#   [21],
#   [22],
#   [25]],
#  [1262.619995,
#   1261.290039,
#   1260.109985,
#   1273.73999,
#   1291.369995,
#   1292.030029,
#   1291.800049,
#   1308.859985,
#   1311.369995,
#   1299.189941,
#   1298.800049,
#   1298.0,
#   1311.459961,
#   1334.869995,
#   1320.699951,
#   1315.459961,
#   1303.050049,
#   1301.349976,
#   1295.339966,
#   1306.689941])

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
regr = make_pipeline(StandardScaler(), SVR(C=1000.0,kernel = 'rbf', epsilon=0.2, gamma = 0.15))
regr.fit(days, Adj_closes)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(C=1000.0, epsilon=0.2, gamma=0.15))])

# %%
regr1 = make_pipeline(StandardScaler(), SVR(C=1000.0,kernel = 'linear', epsilon=0.2))
regr1.fit(days, Adj_closes)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(C=1000.0, epsilon=0.2, kernel='linear'))])

# %%
regr2 = make_pipeline(StandardScaler(), SVR(C=1000.0,kernel = 'poly', epsilon=0.2, degree = 2))
regr2.fit(days, Adj_closes)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(C=1000.0, degree=2, epsilon=0.2, kernel='poly'))])

# %%
day = [[30]]

# %%
pred = regr.predict(day)
pred
# Out:
# array([1261.49008604])

# %%
regr1.predict(day)
# Out:
# array([1303.29998229])

# %%
regr2.predict(day)
# Out:
# array([1266.75635335])

# %%
#visualizing the results to check the bet fit kernel
import matplotlib.pyplot as plt

plt.figure(figsize =(15, 7))
plt.scatter(days, Adj_closes, color= 'black', label= 'Orginal Data')
plt.plot(days, regr.predict(days), color = 'orange', label ='RBF')
plt.plot(days, regr1.predict(days), color = 'red', label ='Poly')
plt.plot(days, regr2.predict(days), color = 'green', label='Linear')
plt.legend()
plt.show()

# %%
actual_price['Adj Close']
# Out:
# 20    1313.550049
# Name: Adj Close, dtype: float64

# %%
#visualizing the results to check the bet fit kernel
import matplotlib.pyplot as plt

plt.figure(figsize =(15, 7))
plt.title('Adjacent Close Price')
plt.plot(data1['Adj Close'])
plt.xlabel('Days')
plt.ylabel('Adj Close')
plt.show()

# %%
## multiple linear regression model

import numpy as np
from sklearn import linear_model

lin = linear_model.LinearRegression()
lin.fit(days, Adj_closes)
# Out:
# LinearRegression()

# %%
lin.predict(day)
# Out:
# array([1286.98847937])
